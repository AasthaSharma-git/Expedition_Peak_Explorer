# %%
import pandas as pd
import json

# %%
with open("../data/raw_peaks.json", encoding="utf-8") as f:
    raw = json.load(f)

df = pd.DataFrame(raw["data"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23 non-null     str
#  1   name                        23 non-null     str
#  2   alternate_names             23 non-null     object
#  3   wikipedia_url               13 non-null     str
#  4   altitude_m                  23 non-null     int64
#  5   range                       23 non-null     str
#  6   region                      23 non-null     str
#  7   country                     23 non-null     str
#  8   district                    23 non-null     str
#  9   nearest_town                23 non-null     str
#  10  accessible_from             23 non-null     object
#  11  coordinates                 23 non-null     object
#  12  technical_grade             23 non-null     str
#  13  imf_band                    18 non-null     str
# ...

# %%
df.head()
# Out:
#                id            name  \
# 0      black-peak      Black Peak
# 1    kang-yatse-2   Kang Yatse II
# 2    kang-yatse-1    Kang Yatse I
# 3  dzo-jongo-east  Dzo Jongo East
# 4       ut-kangri       UT Kangri
#
#                                alternate_names  \
# 0                          [Kalanag, Kala Nag]
# 1  [Kang Yatse 2, Kangyatse II, Kang Yatze II]
# 2    [Kang Yatse 1, Kangyatse I, Kang Yatze I]
# 3                   [Dzo Jongo (E), Dzo Jongo]
# 4                                           []
#
#                                wikipedia_url  altitude_m  \
# 0  https://en.wikipedia.org/wiki/Bandarpunch        6387
# 1   https://en.wikipedia.org/wiki/Kang_Yatse        6250
# 2   https://en.wikipedia.org/wiki/Kang_Yatse        6400
# 3                                        NaN        6217
# 4                                        NaN        6070
#
#                                            range       region country  \
# ...

# %%
df.shape
# Out:
# (23, 44)

# %%
df.isnull().sum()
# Out:
# id                             0
# name                           0
# alternate_names                0
# wikipedia_url                 10
# altitude_m                     0
# range                          0
# region                         0
# country                        0
# district                       0
# nearest_town                   0
# accessible_from                0
# coordinates                    0
# technical_grade                0
# imf_band                       5
# imf_royalty_usd_party_of_2     5
# imf_listed                     0
# open_peak                      0
# inner_line_permit_required     0
# best_months                    0
# typical_duration_days          0
# nights_above_5000m             0
# operator_cost_inr_band         0
# bmc_recommended_first_peak     0
# first_6000er_filter_pass       0
# tvt_operated                   0
# tvt_url                       19
# gpx_available                  0
# key_skills                     0
# ...

# %%
df['technical_grade'].value_counts()
# Out:
# technical_grade
# PD     8
# PD+    4
# AD     4
# AD+    3
# AD-    2
# F+     1
# TD     1
# Name: count, dtype: int64

# %%
df['imf_listed'].value_counts()
# Out:
# imf_listed
# True     18
# False     5
# Name: count, dtype: int64
